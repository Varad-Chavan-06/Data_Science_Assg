# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Bengaluru_House_Data.csv')       #loading dataset
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f1dabe3a25e7> in <cell line: 1>()
# ----> 1 df=pd.read_csv('/content/Bengaluru_House_Data.csv')       #loading dataset
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.head( )

# %%
df.info

# %%
df.shape

# %%
df.fillna('NA',inplace=True)
print(df)                                 #filling null values with NA

# %%
df.replace('NA',0,inplace=True)         #Replacing NA with 0

# %%
df.isnull().sum()

# %%
df.dtypes

# %%
df['area_type']=df['area_type'].astype('category').cat.codes
#converting text data into a particular integar assigned to specific string

# %%
df.head()

# %%
df['location']=df['location'].astype('category').cat.codes

# %%
df.head()

# %%
df['size']=df['size'].astype('category').cat.codes

# %%
df.head()

# %%
df['availability']=df['availability'].astype('category').cat.codes

# %%
df.head()

# %%
df['availability'] = df['availability'].astype('category')
#df['Embarked'] = df['Embarked'].astype('category')
print("\nAfter convert categorial variable:")                       #change datatypes
print(df.dtypes)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
le.fit_transform(x[:,0])         #label encoding

# %%
#one hot encoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('onehot',OneHotEncoder(),[0])],remainder='passthrough')
x = ct.fit_transform(x)
print(x)

# %%
# Perform one-hot encoding for categorical variables
titanic_df = pd.get_dummies(titanic_df, columns=['Sex', 'Embarked'])
print(titanic_df)

# %%
from sklearn.preprocessing import StandardScaler
std_sca=StandardScaler()
x_std=std_sca.fit_transform(x)
print(pd.DataFrame(x_std))

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer()
si.fit_transform(x[:,1:2])
